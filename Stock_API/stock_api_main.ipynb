# %%
STOCK_NAME = "TSLA"
COMPANY_NAME = "Tesla"

STOCK_ENDPOINT = "https://www.alphavantage.co/query"
NEWS_ENDPOINT = "https://newsapi.org/v2/everything"

# STEP 1: Use https://www.alphavantage.co/documentation/#daily
# When stock price increase/decreases by 5% between yesterday and the day before yesterday then print("Get News").
#C1QS6QM80E8KTBVS

# %% [markdown]
# TODO 1. - Get yesterday's closing stock price. Hint: You can perform list comprehensions on Python dictionaries. e.g. [new_value for (key, value) in dictionary.items()]

# %%
import requests
import json
from pprint import pp

stock_param={
    "function":"TIME_SERIES_DAILY_ADJUSTED",
    'symbol':STOCK_NAME,

    'apikey':'C1QS6QM80E8KTBVS'

}

response=requests.get(STOCK_ENDPOINT,params=stock_param)
r=response.json()['Time Series (Daily)']

# %%
pp(r)
# Out:
# {'2023-04-27': {'1. open': '152.64',
#                 '2. high': '160.48',
#                 '3. low': '152.37',
#                 '4. close': '160.19',
#                 '5. adjusted close': '160.19',
#                 '6. volume': '127015177',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-26': {'1. open': '160.29',
#                 '2. high': '160.67',
#                 '3. low': '153.14',
#                 '4. close': '153.75',
#                 '5. adjusted close': '153.75',
#                 '6. volume': '152247096',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-25': {'1. open': '159.82',
#                 '2. high': '163.47',
#                 '3. low': '158.75',
#                 '4. close': '160.67',
#                 '5. adjusted close': '160.67',
#                 '6. volume': '121999312',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-24': {'1. open': '164.65',
#                 '2. high': '165.65',
#                 '3. low': '158.61',
#                 '4. close': '162.55',
#                 '5. adjusted close': '162.55',
#                 '6. volume': '140006559',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-21': {'1. open': '164.8',
#                 '2. high': '166.0',
#                 '3. low': '161.3208',
#                 '4. close': '165.08',
#                 '5. adjusted close': '165.08',
#                 '6. volume': '123538954',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-20': {'1. open': '166.165',
#                 '2. high': '169.7',
#                 '3. low': '160.56',
#                 '4. close': '162.99',
#                 '5. adjusted close': '162.99',
#                 '6. volume': '210970819',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-19': {'1. open': '179.1',
#                 '2. high': '183.5',
#                 '3. low': '177.65',
#                 '4. close': '180.59',
#                 '5. adjusted close': '180.59',
#                 '6. volume': '125732687',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-18': {'1. open': '187.15',
#                 '2. high': '187.69',
#                 '3. low': '183.5775',
#                 '4. close': '184.31',
#                 '5. adjusted close': '184.31',
#                 '6. volume': '92067016',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-17': {'1. open': '186.32',
#                 '2. high': '189.69',
#                 '3. low': '182.69',
#                 '4. close': '187.04',
#                 '5. adjusted close': '187.04',
#                 '6. volume': '116177121',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-14': {'1. open': '183.95',
#                 '2. high': '186.28',
#                 '3. low': '182.01',
#                 '4. close': '185.0',
#                 '5. adjusted close': '185.0',
#                 '6. volume': '96438664',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-13': {'1. open': '182.955',
#                 '2. high': '186.5',
#                 '3. low': '180.94',
#                 '4. close': '185.9',
#                 '5. adjusted close': '185.9',
#                 '6. volume': '112932985',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-12': {'1. open': '190.74',
#                 '2. high': '191.5846',
#                 '3. low': '180.31',
#                 '4. close': '180.54',
#                 '5. adjusted close': '180.54',
#                 '6. volume': '150256278',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-11': {'1. open': '186.69',
#                 '2. high': '189.19',
#                 '3. low': '185.6475',
#                 '4. close': '186.79',
#                 '5. adjusted close': '186.79',
#                 '6. volume': '115770892',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-10': {'1. open': '179.94',
#                 '2. high': '185.1',
#                 '3. low': '176.11',
#                 '4. close': '184.51',
#                 '5. adjusted close': '184.51',
#                 '6. volume': '142154637',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-06': {'1. open': '183.08',
#                 '2. high': '186.39',
#                 '3. low': '179.74',
#                 '4. close': '185.06',
#                 '5. adjusted close': '185.06',
#                 '6. volume': '123857932',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-05': {'1. open': '190.515',
#                 '2. high': '190.68',
#                 '3. low': '183.76',
#                 '4. close': '185.52',
#                 '5. adjusted close': '185.52',
#                 '6. volume': '133882493',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-04': {'1. open': '197.32',
#                 '2. high': '198.7446',
#                 '3. low': '190.32',
#                 '4. close': '192.58',
#                 '5. adjusted close': '192.58',
#                 '6. volume': '126463845',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-04-03': {'1. open': '199.91',
#                 '2. high': '202.6897',
#                 '3. low': '192.2',
#                 '4. close': '194.77',
#                 '5. adjusted close': '194.77',
#                 '6. volume': '169545900',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-31': {'1. open': '197.53',
#                 '2. high': '207.79',
#                 '3. low': '197.2',
#                 '4. close': '207.46',
#                 '5. adjusted close': '207.46',
#                 '6. volume': '170222118',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-30': {'1. open': '195.58',
#                 '2. high': '197.33',
#                 '3. low': '194.42',
#                 '4. close': '195.28',
#                 '5. adjusted close': '195.28',
#                 '6. volume': '110252238',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-29': {'1. open': '193.13',
#                 '2. high': '195.29',
#                 '3. low': '189.44',
#                 '4. close': '193.88',
#                 '5. adjusted close': '193.88',
#                 '6. volume': '123660026',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-28': {'1. open': '192.0',
#                 '2. high': '192.35',
#                 '3. low': '185.43',
#                 '4. close': '189.19',
#                 '5. adjusted close': '189.19',
#                 '6. volume': '98654635',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-27': {'1. open': '194.415',
#                 '2. high': '197.39',
#                 '3. low': '189.94',
#                 '4. close': '191.81',
#                 '5. adjusted close': '191.81',
#                 '6. volume': '120851587',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-24': {'1. open': '191.65',
#                 '2. high': '192.36',
#                 '3. low': '187.15',
#                 '4. close': '190.41',
#                 '5. adjusted close': '190.41',
#                 '6. volume': '116531584',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-23': {'1. open': '195.26',
#                 '2. high': '199.31',
#                 '3. low': '188.65',
#                 '4. close': '192.22',
#                 '5. adjusted close': '192.22',
#                 '6. volume': '144193876',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-22': {'1. open': '199.3',
#                 '2. high': '200.66',
#                 '3. low': '190.95',
#                 '4. close': '191.15',
#                 '5. adjusted close': '191.15',
#                 '6. volume': '150376373',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-21': {'1. open': '188.28',
#                 '2. high': '198.0',
#                 '3. low': '188.04',
#                 '4. close': '197.58',
#                 '5. adjusted close': '197.58',
#                 '6. volume': '153391444',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-20': {'1. open': '178.08',
#                 '2. high': '186.44',
#                 '3. low': '176.35',
#                 '4. close': '183.25',
#                 '5. adjusted close': '183.25',
#                 '6. volume': '129684359',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-17': {'1. open': '184.515',
#                 '2. high': '186.2199',
#                 '3. low': '177.33',
#                 '4. close': '180.13',
#                 '5. adjusted close': '180.13',
#                 '6. volume': '133197140',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-16': {'1. open': '180.365',
#                 '2. high': '185.81',
#                 '3. low': '178.84',
#                 '4. close': '184.13',
#                 '5. adjusted close': '184.13',
#                 '6. volume': '121374453',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-15': {'1. open': '180.8',
#                 '2. high': '182.34',
#                 '3. low': '176.03',
#                 '4. close': '180.45',
#                 '5. adjusted close': '180.45',
#                 '6. volume': '145995583',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-14': {'1. open': '177.31',
#                 '2. high': '183.8',
#                 '3. low': '177.1401',
#                 '4. close': '183.26',
#                 '5. adjusted close': '183.26',
#                 '6. volume': '143717897',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-13': {'1. open': '167.455',
#                 '2. high': '177.35',
#                 '3. low': '163.91',
#                 '4. close': '174.48',
#                 '5. adjusted close': '174.48',
#                 '6. volume': '167790256',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-10': {'1. open': '175.13',
#                 '2. high': '178.29',
#                 '3. low': '168.44',
#                 '4. close': '173.44',
#                 '5. adjusted close': '173.44',
#                 '6. volume': '191488872',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-09': {'1. open': '180.25',
#                 '2. high': '185.18',
#                 '3. low': '172.5124',
#                 '4. close': '172.92',
#                 '5. adjusted close': '172.92',
#                 '6. volume': '170023794',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-08': {'1. open': '185.04',
#                 '2. high': '186.5',
#                 '3. low': '180.0',
#                 '4. close': '182.0',
#                 '5. adjusted close': '182.0',
#                 '6. volume': '151897763',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-07': {'1. open': '191.38',
#                 '2. high': '194.2',
#                 '3. low': '186.1',
#                 '4. close': '187.71',
#                 '5. adjusted close': '187.71',
#                 '6. volume': '148125790',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-06': {'1. open': '198.54',
#                 '2. high': '198.6',
#                 '3. low': '192.3',
#                 '4. close': '193.81',
#                 '5. adjusted close': '193.81',
#                 '6. volume': '128100106',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-03': {'1. open': '194.795',
#                 '2. high': '200.48',
#                 '3. low': '192.88',
#                 '4. close': '197.79',
#                 '5. adjusted close': '197.79',
#                 '6. volume': '154193277',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-02': {'1. open': '186.74',
#                 '2. high': '193.7499',
#                 '3. low': '186.01',
#                 '4. close': '190.9',
#                 '5. adjusted close': '190.9',
#                 '6. volume': '181979154',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-03-01': {'1. open': '206.21',
#                 '2. high': '207.2',
#                 '3. low': '198.52',
#                 '4. close': '202.77',
#                 '5. adjusted close': '202.77',
#                 '6. volume': '156852790',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-28': {'1. open': '210.59',
#                 '2. high': '211.23',
#                 '3. low': '203.75',
#                 '4. close': '205.71',
#                 '5. adjusted close': '205.71',
#                 '6. volume': '153144912',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-27': {'1. open': '202.03',
#                 '2. high': '209.42',
#                 '3. low': '201.26',
#                 '4. close': '207.63',
#                 '5. adjusted close': '207.63',
#                 '6. volume': '161028315',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-24': {'1. open': '196.325',
#                 '2. high': '197.6695',
#                 '3. low': '192.8',
#                 '4. close': '196.88',
#                 '5. adjusted close': '196.88',
#                 '6. volume': '142228105',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-23': {'1. open': '203.91',
#                 '2. high': '205.14',
#                 '3. low': '196.33',
#                 '4. close': '202.07',
#                 '5. adjusted close': '202.07',
#                 '6. volume': '146359950',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-22': {'1. open': '197.93',
#                 '2. high': '201.99',
#                 '3. low': '191.78',
#                 '4. close': '200.86',
#                 '5. adjusted close': '200.86',
#                 '6. volume': '191828457',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-21': {'1. open': '204.99',
#                 '2. high': '209.71',
#                 '3. low': '197.22',
#                 '4. close': '197.37',
#                 '5. adjusted close': '197.37',
#                 '6. volume': '180018588',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-17': {'1. open': '199.985',
#                 '2. high': '208.44',
#                 '3. low': '197.5',
#                 '4. close': '208.31',
#                 '5. adjusted close': '208.31',
#                 '6. volume': '213738549',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-16': {'1. open': '210.78',
#                 '2. high': '217.65',
#                 '3. low': '201.84',
#                 '4. close': '202.04',
#                 '5. adjusted close': '202.04',
#                 '6. volume': '229586538',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-15': {'1. open': '211.755',
#                 '2. high': '214.66',
#                 '3. low': '206.11',
#                 '4. close': '214.24',
#                 '5. adjusted close': '214.24',
#                 '6. volume': '182108581',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-14': {'1. open': '191.94',
#                 '2. high': '209.82',
#                 '3. low': '189.44',
#                 '4. close': '209.25',
#                 '5. adjusted close': '209.25',
#                 '6. volume': '216455708',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-13': {'1. open': '194.415',
#                 '2. high': '196.3',
#                 '3. low': '187.61',
#                 '4. close': '194.64',
#                 '5. adjusted close': '194.64',
#                 '6. volume': '172475452',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-10': {'1. open': '202.225',
#                 '2. high': '206.2',
#                 '3. low': '192.89',
#                 '4. close': '196.89',
#                 '5. adjusted close': '196.89',
#                 '6. volume': '204754129',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-09': {'1. open': '207.775',
#                 '2. high': '214.0',
#                 '3. low': '204.77',
#                 '4. close': '207.32',
#                 '5. adjusted close': '207.32',
#                 '6. volume': '215431442',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-08': {'1. open': '196.1',
#                 '2. high': '203.0',
#                 '3. low': '194.31',
#                 '4. close': '201.29',
#                 '5. adjusted close': '201.29',
#                 '6. volume': '180673644',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-07': {'1. open': '196.43',
#                 '2. high': '197.5',
#                 '3. low': '189.55',
#                 '4. close': '196.81',
#                 '5. adjusted close': '196.81',
#                 '6. volume': '186010325',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-06': {'1. open': '193.01',
#                 '2. high': '198.17',
#                 '3. low': '189.92',
#                 '4. close': '194.76',
#                 '5. adjusted close': '194.76',
#                 '6. volume': '186188131',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-03': {'1. open': '183.95',
#                 '2. high': '199.0',
#                 '3. low': '183.69',
#                 '4. close': '189.98',
#                 '5. adjusted close': '189.98',
#                 '6. volume': '232662023',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-02': {'1. open': '187.325',
#                 '2. high': '196.7501',
#                 '3. low': '182.61',
#                 '4. close': '188.27',
#                 '5. adjusted close': '188.27',
#                 '6. volume': '217448287',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-02-01': {'1. open': '173.89',
#                 '2. high': '183.805',
#                 '3. low': '169.93',
#                 '4. close': '181.41',
#                 '5. adjusted close': '181.41',
#                 '6. volume': '213806323',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-31': {'1. open': '164.57',
#                 '2. high': '174.3',
#                 '3. low': '162.78',
#                 '4. close': '173.22',
#                 '5. adjusted close': '173.22',
#                 '6. volume': '196813541',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-30': {'1. open': '178.05',
#                 '2. high': '179.77',
#                 '3. low': '166.5',
#                 '4. close': '166.66',
#                 '5. adjusted close': '166.66',
#                 '6. volume': '230878807',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-27': {'1. open': '162.43',
#                 '2. high': '180.68',
#                 '3. low': '161.17',
#                 '4. close': '177.9',
#                 '5. adjusted close': '177.9',
#                 '6. volume': '306590613',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-26': {'1. open': '159.965',
#                 '2. high': '161.42',
#                 '3. low': '154.76',
#                 '4. close': '160.27',
#                 '5. adjusted close': '160.27',
#                 '6. volume': '234815090',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-25': {'1. open': '141.905',
#                 '2. high': '146.41',
#                 '3. low': '138.07',
#                 '4. close': '144.43',
#                 '5. adjusted close': '144.43',
#                 '6. volume': '192734347',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-24': {'1. open': '143.0',
#                 '2. high': '146.5',
#                 '3. low': '141.1',
#                 '4. close': '143.89',
#                 '5. adjusted close': '143.89',
#                 '6. volume': '158699056',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-23': {'1. open': '135.87',
#                 '2. high': '145.3793',
#                 '3. low': '134.27',
#                 '4. close': '143.75',
#                 '5. adjusted close': '143.75',
#                 '6. volume': '203119211',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-20': {'1. open': '128.68',
#                 '2. high': '133.51',
#                 '3. low': '127.3466',
#                 '4. close': '133.42',
#                 '5. adjusted close': '133.42',
#                 '6. volume': '138858136',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-19': {'1. open': '127.26',
#                 '2. high': '129.99',
#                 '3. low': '124.3082',
#                 '4. close': '127.17',
#                 '5. adjusted close': '127.17',
#                 '6. volume': '170291880',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-18': {'1. open': '136.555',
#                 '2. high': '136.68',
#                 '3. low': '127.01',
#                 '4. close': '128.78',
#                 '5. adjusted close': '128.78',
#                 '6. volume': '195680318',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-17': {'1. open': '125.695',
#                 '2. high': '131.7',
#                 '3. low': '125.02',
#                 '4. close': '131.49',
#                 '5. adjusted close': '131.49',
#                 '6. volume': '186476985',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-13': {'1. open': '116.55',
#                 '2. high': '122.63',
#                 '3. low': '115.6',
#                 '4. close': '122.4',
#                 '5. adjusted close': '122.4',
#                 '6. volume': '180714119',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-12': {'1. open': '122.56',
#                 '2. high': '124.1311',
#                 '3. low': '117.0',
#                 '4. close': '123.56',
#                 '5. adjusted close': '123.56',
#                 '6. volume': '169400913',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-11': {'1. open': '122.09',
#                 '2. high': '125.95',
#                 '3. low': '120.51',
#                 '4. close': '123.22',
#                 '5. adjusted close': '123.22',
#                 '6. volume': '183810771',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-10': {'1. open': '121.07',
#                 '2. high': '122.76',
#                 '3. low': '114.92',
#                 '4. close': '118.85',
#                 '5. adjusted close': '118.85',
#                 '6. volume': '167642485',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-09': {'1. open': '118.96',
#                 '2. high': '123.52',
#                 '3. low': '117.11',
#                 '4. close': '119.77',
#                 '5. adjusted close': '119.77',
#                 '6. volume': '190283951',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-06': {'1. open': '103.0',
#                 '2. high': '114.39',
#                 '3. low': '101.81',
#                 '4. close': '113.06',
#                 '5. adjusted close': '113.06',
#                 '6. volume': '220911051',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-05': {'1. open': '110.51',
#                 '2. high': '111.75',
#                 '3. low': '107.1601',
#                 '4. close': '110.34',
#                 '5. adjusted close': '110.34',
#                 '6. volume': '157986324',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-04': {'1. open': '109.11',
#                 '2. high': '114.59',
#                 '3. low': '107.52',
#                 '4. close': '113.64',
#                 '5. adjusted close': '113.64',
#                 '6. volume': '180388976',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2023-01-03': {'1. open': '118.47',
#                 '2. high': '118.8',
#                 '3. low': '104.64',
#                 '4. close': '108.1',
#                 '5. adjusted close': '108.1',
#                 '6. volume': '231402818',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-30': {'1. open': '119.95',
#                 '2. high': '124.48',
#                 '3. low': '119.75',
#                 '4. close': '123.18',
#                 '5. adjusted close': '123.18',
#                 '6. volume': '157777339',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-29': {'1. open': '120.385',
#                 '2. high': '123.57',
#                 '3. low': '117.495',
#                 '4. close': '121.82',
#                 '5. adjusted close': '121.82',
#                 '6. volume': '221923313',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-28': {'1. open': '110.35',
#                 '2. high': '116.27',
#                 '3. low': '108.24',
#                 '4. close': '112.71',
#                 '5. adjusted close': '112.71',
#                 '6. volume': '221070537',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-27': {'1. open': '117.495',
#                 '2. high': '119.67',
#                 '3. low': '108.76',
#                 '4. close': '109.1',
#                 '5. adjusted close': '109.1',
#                 '6. volume': '208643444',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-23': {'1. open': '126.37',
#                 '2. high': '128.6173',
#                 '3. low': '121.02',
#                 '4. close': '123.15',
#                 '5. adjusted close': '123.15',
#                 '6. volume': '166989688',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-22': {'1. open': '136.0',
#                 '2. high': '136.63',
#                 '3. low': '122.26',
#                 '4. close': '125.35',
#                 '5. adjusted close': '125.35',
#                 '6. volume': '210090250',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-21': {'1. open': '139.335',
#                 '2. high': '141.26',
#                 '3. low': '135.89',
#                 '4. close': '137.57',
#                 '5. adjusted close': '137.57',
#                 '6. volume': '145417412',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-20': {'1. open': '146.05',
#                 '2. high': '148.47',
#                 '3. low': '137.66',
#                 '4. close': '137.8',
#                 '5. adjusted close': '137.8',
#                 '6. volume': '159563267',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-19': {'1. open': '154.0',
#                 '2. high': '155.25',
#                 '3. low': '145.82',
#                 '4. close': '149.87',
#                 '5. adjusted close': '149.87',
#                 '6. volume': '139390634',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-16': {'1. open': '159.635',
#                 '2. high': '160.99',
#                 '3. low': '150.04',
#                 '4. close': '150.23',
#                 '5. adjusted close': '150.23',
#                 '6. volume': '139032175',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-15': {'1. open': '153.44',
#                 '2. high': '160.9299',
#                 '3. low': '153.28',
#                 '4. close': '157.67',
#                 '5. adjusted close': '157.67',
#                 '6. volume': '122334459',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-14': {'1. open': '159.25',
#                 '2. high': '161.62',
#                 '3. low': '155.31',
#                 '4. close': '156.8',
#                 '5. adjusted close': '156.8',
#                 '6. volume': '140682338',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-13': {'1. open': '174.87',
#                 '2. high': '175.05',
#                 '3. low': '156.91',
#                 '4. close': '160.95',
#                 '5. adjusted close': '160.95',
#                 '6. volume': '175862722',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-12': {'1. open': '176.1',
#                 '2. high': '177.37',
#                 '3. low': '167.52',
#                 '4. close': '167.82',
#                 '5. adjusted close': '167.82',
#                 '6. volume': '109794471',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-09': {'1. open': '173.84',
#                 '2. high': '182.5',
#                 '3. low': '173.36',
#                 '4. close': '179.05',
#                 '5. adjusted close': '179.05',
#                 '6. volume': '104872336',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-08': {'1. open': '172.2',
#                 '2. high': '175.2',
#                 '3. low': '169.06',
#                 '4. close': '173.44',
#                 '5. adjusted close': '173.44',
#                 '6. volume': '97624491',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-07': {'1. open': '175.03',
#                 '2. high': '179.38',
#                 '3. low': '172.218',
#                 '4. close': '174.04',
#                 '5. adjusted close': '174.04',
#                 '6. volume': '84213284',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-06': {'1. open': '181.215',
#                 '2. high': '183.65',
#                 '3. low': '175.33',
#                 '4. close': '179.82',
#                 '5. adjusted close': '179.82',
#                 '6. volume': '92150823',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-05': {'1. open': '189.44',
#                 '2. high': '191.27',
#                 '3. low': '180.55',
#                 '4. close': '182.45',
#                 '5. adjusted close': '182.45',
#                 '6. volume': '93122667',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'},
#  '2022-12-02': {'1. open': '191.78',
#                 '2. high': '196.25',
#                 '3. low': '191.11',
#                 '4. close': '194.86',
#                 '5. adjusted close': '194.86',
#                 '6. volume': '73645922',
#                 '7. dividend amount': '0.0000',
#                 '8. split coefficient': '1.0'}}

# %% [markdown]
# list comphreshsion
# x for x in list
# y for (x,y) in dict.items()

# %%
r['2023-04-27']['4. close']
# Out:
# '160.19'

# %%
data_list=[value for (key,value) in r.items()]
#print(data_list)
yesterday_closing_price=data_list[0]['4. close']
print(yesterday_closing_price)
# Out:
# 160.19

# %%
day_before_yesterday=data_list[1]['4. close']
print(day_before_yesterday)
# Out:
# 153.75

# %%
difference_price=abs(float(day_before_yesterday)-float(yesterday_closing_price))
print(difference_price)
# Out:
# 6.439999999999998

# %%
# TODO 4. - Work out the percentage difference in price between closing price yesterday and closing price the day before yesterday.
percent_diff=(difference_price/float(yesterday_closing_price))*100
print(percent_diff)
# Out:
# 4.020225981646793

# %%
# TODO 5. - If TODO4 percentage is greater than 5 then print("Get News").
if(percent_diff>2):
    news_parmas={
    'q':'stock',
    'qInTitle':'COMPANY_NAME',
    'apiKey':'948ef77210504ebc9a2012723be8c5e3'
    }

    response=requests.get(NEWS_ENDPOINT,params=news_parmas)
    NEWS_R=response.json()['articles']
    pp(NEWS_R)
    print("get news")
# Out:
# [{'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Igor Bonifacic',
#   'title': 'Court rules Elon Musk broke federal labor law with 2018 tweet',
#   'description': 'Elon Musk broke US labor law in 2018 when he tweeted\r\n'
#                  ' Tesla factory workers would forgo stock options if they '
#                  'chose to unionize, according to a federal appeals court. On '
#                  'Friday, the Fifth Circuit Court of Appeals, in a decision '
#                  'spotted by Business Insider\r\n'
#                  ',…',
#   'url': 'https://www.engadget.com/court-rules-elon-musk-broke-federal-labor-law-with-2018-tweet-195420903.html',
#   'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/2bHdZ1.RA1gHDSFt2ZzVRA--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2022-08/ad22f730-265c-11ed-bbef-da7b65eec5cc.cf.jpg',
#   'publishedAt': '2023-04-01T19:54:20Z',
#   'content': 'Elon Musk broke US labor law in 2018 when he tweeted\r\n'
#              ' Tesla factory workers would forgo stock options if they chose '
#              'to unionize, according to a federal appeals court. On Friday, '
#              'the Fifth Circuit Co… [+1998 chars]'},
#  {'source': {'id': None, 'name': 'Lifehacker.com'},
#   'author': 'Jeff Somers',
#   'title': 'Make These Renovations Before Retirement If You Plan to Stay in '
#            'Your Home',
#   'description': 'Aging is something we all have to deal with—financially, '
#                  'spiritually, and physically. That last part means taking '
#                  'stock of your living situation. While many people plan to '
#                  'move to a different home, relocate to a senior community, or '
#                  'bunk down with family, som…',
#   'url': 'https://lifehacker.com/make-these-renovations-before-retirement-if-you-plan-to-1850337333',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ce6b1404d0e7a5ad8a91728f3d12e002.jpg',
#   'publishedAt': '2023-04-17T16:00:00Z',
#   'content': 'Aging is something we all have to deal withfinancially, '
#              'spiritually, and physically. That last part means taking stock '
#              'of your living situation. While many people plan to move to a '
#              'different home, re… [+5159 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Jordan Valinsky',
#   'title': 'Tupperware stock plunges after warning it could go out of business',
#   'description': 'Tupperware shares fell as much as 40% in premarket trading '
#                  'Monday following a bleak warning that its future is looking '
#                  'murky.',
#   'url': 'https://www.cnn.com/2023/04/10/investing/tupperware-trouble/index.html',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/221020141017-04-new-tupperware.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2023-04-10T12:50:17Z',
#   'content': 'Tupperware shares fell as much as 40% in premarket trading '
#              'Monday following a bleak warning that its future is looking '
#              'murky.\r\n'
#              'In a regulatory filing late Friday, the container maker said '
#              'theres subs… [+1582 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': "Column: AMC Entertainment's $100 million meme stock settlement ... "
#            '- Reuters',
#   'description': "Column: AMC Entertainment's $100 million meme stock "
#                  'settlement ...\xa0\xa0Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMigAFodHRwczovL3d3dy5yZXV0ZXJzLmNvbS9sZWdhbC9nb3Zlcm5tZW50L2NvbHVtbi1hbWMtZW50ZXJ0YWlubWVudHMtMTAwLW1pbGxpb24tbWVtZS1zdG9jay1zZXR0bGVtZW50LWRlcGVuZHMtdW51c3VhbC0yMDIzLTA0LTA0L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-04T21:07:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Long April break gives F1 time to take stock - Reuters',
#   'description': 'Long April break gives F1 time to take stock\xa0\xa0Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiXmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2xpZmVzdHlsZS9zcG9ydHMvbG9uZy1hcHJpbC1icmVhay1naXZlcy1mMS10aW1lLXRha2Utc3RvY2stMjAyMy0wNC0wMy_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-03T12:37:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Oil prices rise on US crude, fuel stock draws - Reuters.com',
#   'description': 'Oil prices rise on US crude, fuel stock draws\xa0\xa0'
#                  'Reuters.com',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiXWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL2VuZXJneS9vaWwtcHJpY2VzLXJpc2UtdXMtY3J1ZGUtZnVlbC1zdG9jay1kcmF3cy0yMDIzLTA0LTI2L9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-26T00:30:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'British EV startup Arrival announces reverse stock split - Reuters',
#   'description': 'British EV startup Arrival announces reverse stock '
#                  'split\xa0\xa0Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiemh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL2F1dG9zLXRyYW5zcG9ydGF0aW9uL2JyaXRpc2gtZXYtc3RhcnR1cC1hcnJpdmFsLWFubm91bmNlcy1yZXZlcnNlLXN0b2NrLXNwbGl0LTIwMjMtMDQtMTEv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-11T13:28:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'London Stock Exchange Group reaffirms 2023 outlook - Reuters',
#   'description': 'London Stock Exchange Group reaffirms 2023 outlook\xa0\xa0'
#                  'Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiX2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL3VrL2xvbmRvbi1zdG9jay1leGNoYW5nZS1ncm91cC1yZWFmZmlybXMtMjAyMy1vdXRsb29rLTIwMjMtMDQtMjcv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-27T06:28:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#   'author': 'Ron Amadeo',
#   'title': 'Google is killing third-party Google Assistant smart displays',
#   'description': 'Software support is dead, and all the hardware is out of '
#                  'stock.',
#   'url': 'https://arstechnica.com/gadgets/2023/04/google-is-killing-third-party-google-assistant-smart-displays/',
#   'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2023/04/12-760x380.jpg',
#   'publishedAt': '2023-04-10T17:24:49Z',
#   'content': '10 with \r\n'
#              '<ul><li>\r\n'
#              ' The Lenovo Smart Display 7: The newest (2019) third-party smart '
#              'display out there. \r\n'
#              '</li><li>\r\n'
#              ' This Lenovo Google Assistant Smart Display is the first device '
#              'to ship with Andro… [+3906 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Kyle Barr',
#   'title': 'Apple Might Be Ditching Touch-Based Buttons on iPhone 15',
#   'description': 'Just what the hell is happening with the iPhone 15’s '
#                  'external buttons? Despite numerous leaks and countless '
#                  'reports that premium iPhone 15s would ditch physical buttons '
#                  'and get new, trackpad-like touch-based controls, the '
#                  'Cupertino company may have made a las…',
#   'url': 'https://gizmodo.com/apple-iphone-15-taptic-touch-buttons-kuo-leak-stocks-1850329674',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/b558aca2b1840775126207dd108844af.jpg',
#   'publishedAt': '2023-04-12T21:35:00Z',
#   'content': 'Just what the hell is happening with the iPhone 15s external '
#              'buttons? Despite numerous leaks and countless reports that '
#              'premium iPhone 15s would ditch physical buttons and get new, '
#              'trackpad-like touc… [+3383 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'jsor@insider.com (Jennifer Sor)',
#   'title': "The downside risk to the stock market is the highest it's been in "
#            "a year as earnings face pressure, Morgan Stanley's chief stock "
#            'strategist says',
#   'description': "Previously, Morgan Stanley's top stock strategist predicted "
#                  'the market would suffer its worst earnings recession since '
#                  '2008.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-outlook-bear-market-earnings-recession-risk-morgan-stanley-2023-3',
#   'urlToImage': 'https://i.insider.com/5a833949d03072f60a8b4842?width=1200&format=jpeg',
#   'publishedAt': '2023-03-27T19:01:18Z',
#   'content': "The downside risk to the stock market is the highest it's been "
#              'in a year, as firms are still set to battle earnings pressure '
#              "amid tough economic conditions, according to Morgan Stanley's "
#              'chief stock … [+1805 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': "TD world's most shorted banking stock, shares down -ORTEX data - "
#            'Reuters.com',
#   'description': "TD world's most shorted banking stock, shares down -ORTEX "
#                  'data\xa0\xa0Reuters.com',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2FtZXJpY2FzL3RkLXdvcmxkcy1tb3N0LXNob3J0ZWQtYmFua2luZy1zdG9jay1zaGFyZXMtZG93bi1vcnRleC1kYXRhLTIwMjMtMDQtMDUv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-05T19:06:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Analysis: Debt ceiling worries bubble up in US stock options '
#            'market - Reuters',
#   'description': 'Analysis: Debt ceiling worries bubble up in US stock options '
#                  'market\xa0\xa0Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiZWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL21hcmtldHMvdXMvZGVidC1jZWlsaW5nLXdvcnJpZXMtYnViYmxlLXVwLXVzLXN0b2NrLW9wdGlvbnMtbWFya2V0LTIwMjMtMDQtMjYv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-26T05:07:19Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Twitter joins eToro to let users see real-time stock information - '
#            'Reuters',
#   'description': 'Twitter joins eToro to let users see real-time stock '
#                  'information\xa0\xa0Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3RlY2hub2xvZ3kvdHdpdHRlci1qb2lucy1ldG9yby1sZXQtdXNlcnMtc2VlLXJlYWwtdGltZS1zdG9jay1pbmZvcm1hdGlvbi0yMDIzLTA0LTEzL9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-13T10:59:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': "India's milk imports soar as disease hits local cattle stock - "
#            'Reuters India',
#   'description': "India's milk imports soar as disease hits local cattle "
#                  'stock\xa0\xa0Reuters India',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiaGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2luZGlhL2luZGlhcy1taWxrLWltcG9ydHMtc29hci1kaXNlYXNlLWhpdHMtbG9jYWwtY2F0dGxlLXN0b2NrLTIwMjMtMDQtMDQv0gEA?oc%3D5%26hl%3Den-CA%26gl%3DCA%26ceid%3DCA:en&gl=FR&hl=en-CA&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-04T03:34:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Nikola tumbles to record low on $100 million stock sale - Reuters',
#   'description': 'Nikola tumbles to record low on $100 million stock '
#                  'sale\xa0\xa0Reuters',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMicmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL2F1dG9zLXRyYW5zcG9ydGF0aW9uL25pa29sYS10dW1ibGVzLXJlY29yZC1sb3ctMTAwLW1pbGxpb24tc3RvY2stc2FsZS0yMDIzLTAzLTMxL9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-03-31T15:14:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Lauren Leffer',
#   'title': "Jack Dorsey's Block Rebuffs Cash App Fraud Allegations With Data "
#            'Disclosure',
#   'description': 'Block, the Jack Dorsey-owned parent company of Cash App, is '
#                  'contesting accusations of fraud and rampant fake accounts '
#                  'with a new data disclosure. In a Thursday memo to investors, '
#                  'the company claimed that 44 million of Cash App’s total 52 '
#                  'million active monthl…',
#   'url': 'https://gizmodo.com/jack-dorsey-block-cashapp-digital-payment-1850285000',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/3418aad77e6e8af473506bf811fb8f76.jpg',
#   'publishedAt': '2023-03-30T21:25:00Z',
#   'content': 'Block, the Jack Dorsey-owned parent company of Cash App, is '
#              'contesting accusations of fraud and rampant fake accounts with a '
#              'new data disclosure. In a Thursday memo to investors, the '
#              'company claimed … [+2091 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Jeanne Sahadi',
#   'title': 'Beyond FDIC insurance: How protected is your money outside of '
#            'banks?',
#   'description': 'Just as stock market turmoil is a good reminder to make sure '
#                  'your investment portfolio is diversified, a few surprise '
#                  'bank failures is a good excuse to find out whether your '
#                  'financial accounts — not just your checking and savings '
#                  'accounts — are all protected …',
#   'url': 'https://www.cnn.com/2023/03/28/success/protections-insurance-financial-accounts-your-money/index.html',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230317155426-financial-security-stock.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2023-03-28T14:06:07Z',
#   'content': 'Just as stock market turmoil is a good reminder to make sure '
#              'your investment portfolio is diversified, a few surprise bank '
#              'failures is a good excuse to find out whether your financial '
#              'accounts not ju… [+5748 chars]'},
#  {'source': {'id': None, 'name': 'ReadWrite'},
#   'author': 'Priyank Soni',
#   'title': 'Algorithmic Trading Revolutionizes Stock Market Trading in India',
#   'description': 'Many investors and traders choose stocks as the financial '
#                  'instrument to trade with due to the high-profit potential '
#                  'available. During this trading experience, one must stay '
#                  'aware of the market changes. Like the rise or fall of stock '
#                  'value. Thus, it is importa…',
#   'url': 'https://readwrite.com/algorithmic-trading-revolutionizes-stock-market-trading-in-india/',
#   'urlToImage': 'https://readwrite.com/wp-content/uploads/2023/02/Algorithmic-Trading-Stock-Market.jpg',
#   'publishedAt': '2023-03-31T21:00:08Z',
#   'content': 'Many investors and traders choose stocks as the financial '
#              'instrument to trade with due to the high-profit potential '
#              'available. During this trading experience, one must stay aware '
#              'of the market change… [+7463 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Igor Bonifacic',
#   'title': 'YouTube Music contractors vote overwhelmingly to unionize in '
#            'landmark election',
#   'description': 'On Wednesday, a group of contractors at YouTube Music voted '
#                  'to unionize with the Alphabet Workers Union-Communications '
#                  'Workers of America (AWU-CWA). Out of the 49 workers who were '
#                  'eligible to vote, 41 voted in favor of the action, with the '
#                  'remaining eight abs…',
#   'url': 'https://www.engadget.com/youtube-music-contractors-vote-overwhelmingly-to-unionize-in-landmark-election-213844906.html',
#   'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/sBsdBENx0Xc8qM5n1LdeJQ--~B/Zmk9ZmlsbDtoPTYzMDtweW9mZj0wO3c9MTIwMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2023-02/1d566f40-b213-11ed-b7bd-407203ed25ca.cf.jpg',
#   'publishedAt': '2023-04-26T21:38:44Z',
#   'content': 'On Wednesday, a group of contractors at YouTube Music voted to '
#              'unionize with the Alphabet Workers Union-Communications Workers '
#              'of America (AWU-CWA). Out of the 49 workers who were eligible to '
#              'vote, 4… [+1828 chars]'},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Hanna Ziady',
#   'title': 'Sonic the Hedgehog, meet Angry Birds. Sega is buying Rovio',
#   'description': "Japan's Sega, the company behind Sonic the Hedgehog, is "
#                  'buying Rovio Entertainment in a cash deal that values the '
#                  'creator of Angry Birds at €706 million ($774 million).',
#   'url': 'https://www.cnn.com/2023/04/17/media/angry-birds-rovio-sega-acquisition/index.html',
#   'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230417095045-sonic-the-hedgehog-angry-birds-split.jpg?c=16x9&q=w_800,c_fill',
#   'publishedAt': '2023-04-17T10:49:30Z',
#   'content': 'Japans Sega, the company behind Sonic the Hedgehog, is buying '
#              'Rovio Entertainment in a cash deal that values the creator of '
#              'Angry Birds at 706 million ($774 million).\r\n'
#              'The Finnish video game develope… [+1932 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Stock futures are flat Monday night as Wall Street looks to tech '
#            'earnings: Live updates - CNBC',
#   'description': '<ol><li>Stock futures are flat Monday night as Wall Street '
#                  'looks to tech earnings: Live updates\xa0\xa0CNBC\r\n'
#                  '</li><li>Stocks fall ahead of more heavyweight earnings: '
#                  'Stock market news today\xa0\xa0Yahoo Canada Finance\r\n'
#                  '</li><li>Markets Today: Stock Index Futures Slightly…',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiRGh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjMvMDQvMjQvc3RvY2stbWFya2V0LXRvZGF5LWxpdmUtdXBkYXRlcy5odG1s0gFIaHR0cHM6Ly93d3cuY25iYy5jb20vYW1wLzIwMjMvMDQvMjQvc3RvY2stbWFya2V0LXRvZGF5LWxpdmUtdXBkYXRlcy5odG1s?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-24T22:21:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Phil Rosen',
#   'title': 'Markets are ignoring recession signals because a downturn might '
#            'actually ease a handful of problems facing stocks',
#   'description': "Insider's Phil Rosen breaks down the stock market trends "
#                  'that could alleviate in a recession.',
#   'url': 'https://www.businessinsider.com/markets-investing-recession-signs-downturn-stocks-datatrek-wall-street-finance-2023-4',
#   'urlToImage': 'https://i.insider.com/6442c81a77ecc80019e5c8a0?width=1200&format=jpeg',
#   'publishedAt': '2023-04-24T10:00:09Z',
#   'content': "Phew! Hey readers — I'm Phil Rosen. I'm still in shock after "
#              "last night's episode of Succession — no spoilers, but dang(!). "
#              "Talk about drama.\xa0Today we're diving into how a recession "
#              'could affect the … [+3788 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Morgan Chittum',
#   'title': 'Investors should be wary of US stocks as the damage from Fed '
#            "tightening hasn't yet been reflected in markets, BlackRock "
#            'strategist says',
#   'description': "Despite the stock market's resilience this year, a top "
#                  'BlackRock strategist urged caution about equities investing.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-outlook-blackrock-fed-rate-hikes-earnings-inflation-economy-2023-4',
#   'urlToImage': 'https://i.insider.com/5e6a56b6235c185e683aa1a5?width=1200&format=jpeg',
#   'publishedAt': '2023-04-25T18:27:32Z',
#   'content': "Despite the market's resiliency this year, a BlackRock "
#              'strategist says to be cautious of equities.Spencer Platt/Getty '
#              'Images\r\n'
#              '<ul>\n'
#              "<li>A BlackRock strategist said the US stock market hasn't fully "
#              'pri… [+2014 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Morgan Chittum',
#   'title': 'US stocks rise as Big Tech earnings stay strong and US GDP growth '
#            'slows',
#   'description': 'Meta Platforms stock jumped after reporting first-quarter '
#                  "results that beat Wall Street's estimates.",
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-meta-facebook-instagram-big-tech-gdp-growth-2023-4',
#   'urlToImage': 'https://i.insider.com/640f546aa3b2a10018b2b2f1?width=1200&format=jpeg',
#   'publishedAt': '2023-04-27T13:45:37Z',
#   'content': 'TIMOTHY A. CLARY / Getty\r\n'
#              '<ul>\n'
#              '<li>US stocks rose as Big Tech earnings stayed strong while US '
#              'GDP growths slowed.\xa0</li>\n'
#              '<li>Meta stock jumped after reporting first-quarter results that '
#              'beat Wall Stre… [+1756 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'William Antonelli,Brendan Griffiths',
#   'title': 'Where to buy Nvidia RTX 4070: Stock and preorders available at '
#            'these stores',
#   'description': "The GeForce RTX 4070 is Nvidia's newest GPU, made to support "
#                  '4K gaming and streaming, and is out now from just $599.',
#   'url': 'https://www.businessinsider.com/guides/tech/nvidia-geforce-rtx-4070-price-stock-where-to-buy',
#   'urlToImage': 'https://i.insider.com/6437179be955f50018faa5ba?width=1200&format=jpeg',
#   'publishedAt': '2023-04-13T10:37:52Z',
#   'content': 'When you buy through our links, Insider may earn an affiliate '
#              'commission. Learn more.\r\n'
#              "If you're looking for where to buy the RTX 4070 today, we're "
#              'here to make your search much easier. RTX 4070 preo… [+3069 '
#              'chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': "There's a simple reason why it's very likely that the stock market "
#            'bottomed in October',
#   'description': 'But just because the stock market may have hit its bear '
#                  "market low, that doesn't mean new highs are right around the "
#                  'corner.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-likely-bottom-october-fundstrat-new-bull-rally-sp500-2023-3',
#   'urlToImage': 'https://i.insider.com/636027335ff33600197570d7?width=1200&format=jpeg',
#   'publishedAt': '2023-03-31T17:35:35Z',
#   'content': '(Photo by Scott Heins/Getty Images)\r\n'
#              "<ul><li>The stock market's October low likely represented the "
#              'bottom of the bear market, according to '
#              "Fundstrat.</li><li>That's because 50% of bear markets since … "
#              '[+2441 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'tmohamed@insider.com (Theron Mohamed)',
#   'title': 'Warren Buffett shakes off recession fears as he piles another $216 '
#            'million into Occidental Petroleum stock',
#   'description': "Warren Buffett's Berkshire Hathaway ramped up its bet on "
#                  'Occidental Petroleum, securing a 23.6% stake worth about $13 '
#                  'billion.',
#   'url': 'https://markets.businessinsider.com/news/stocks/warren-buffett-berkshire-hathaway-inflation-recession-economy-occidental-petroleum-stock-2023-3',
#   'urlToImage': 'https://i.insider.com/56f17c909105841c008b807a?width=1200&format=jpeg',
#   'publishedAt': '2023-03-28T10:49:31Z',
#   'content': 'US investors face a thorny combination of rising interest rates, '
#              'stubborn inflation, a looming recession, and a potential credit '
#              'crunch. Warren Buffett is forging ahead with stock purchases '
#              'anyway.\r\n'
#              '… [+2350 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': 'An under-the-radar stock market indicator is pointing to more '
#            'gains ahead',
#   'description': '"It would be quite abnormal to expect a massive bear market '
#                  'and a horrible year for stocks this year," Carson Group\'s '
#                  'Ryan Detrick said.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-outlook-signal-under-the-radar-indicator-upside-ahead-2023-4',
#   'urlToImage': 'https://i.insider.com/5f3a828fe89ebf001f04527d?width=1200&format=jpeg',
#   'publishedAt': '2023-04-07T15:50:33Z',
#   'content': 'Spencer Platt/Getty Images\r\n'
#              '<ul><li>An under-the-radar stock market indicator just flashed, '
#              'suggesting more upside ahead.</li><li>The December Low indicator '
#              'occurs when the S&P 500 stays above its De… [+2082 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': 'An incredibly rare bullish stock market indicator just flashed for '
#            'the first time since 2019',
#   'description': '"This is what you tend to see at the beginning of new '
#                  'bullish phases," Carson Group chief market strategist Ryan '
#                  'Detrick told Insider on Monday.',
#   'url': 'https://markets.businessinsider.com/news/stocks/bullish-stock-market-signal-zweig-breadth-thrust-indicator-just-flashed-2023-4',
#   'urlToImage': 'https://i.insider.com/60f9c96a0729770012b96311?width=1200&format=jpeg',
#   'publishedAt': '2023-04-10T14:04:43Z',
#   'content': 'Spencer Platt/Getty Images\r\n'
#              '<ul><li>An incredibly rare bullish stock market indicator just '
#              'flashed, suggesting more upside ahead.</li><li>The Zweig Breadth '
#              'Thrust indicator flashed for the first time… [+3060 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Phil Rosen',
#   'title': 'Tesla stock tumbles 5% after the EV maker cuts prices again',
#   'description': "Elon Musk's car company surged 68% in the first quarter of "
#                  'the year, though it has tumbled 14% so far in April.',
#   'url': 'https://markets.businessinsider.com/news/stocks/tesla-stock-price-cuts-elon-musk-april-shanghai-factory-car-2023-4',
#   'urlToImage': 'https://i.insider.com/63c1610e33ffb700180f962b?width=1200&format=jpeg',
#   'publishedAt': '2023-04-10T16:21:24Z',
#   'content': 'Elon Musk in front of a TeslaGetty\r\n'
#              '<ul>\n'
#              '<li>Tesla stock fell as much as 5% on Monday following news of '
#              'more price cuts for electric vehicles.</li>\n'
#              '<li>The company also said it will launch a new Shan… [+2110 '
#              'chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Carla Mozée',
#   'title': 'The stock market rally has run its course as earnings highlight '
#            'weakening consumer demand, strategist says',
#   'description': 'Now "is not a time for investors to return to a buy-the-dip '
#                  'mentality," said the investment head at California-based '
#                  'Blanke Schein Wealth Management.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stocks-market-outlook-rally-earnings-economy-tesla-netflix-fed-sp500-2023-4',
#   'urlToImage': 'https://i.insider.com/6113ca37ad63f30019501f8b?width=1200&format=jpeg',
#   'publishedAt': '2023-04-20T19:18:03Z',
#   'content': 'Brendan McDermid/Reuters\r\n'
#              '<ul>\n'
#              '<li>US stocks are near highs for 2023, but the rally looks set '
#              'to fade, the CIO of Blanke Schein Wealth Management said.\xa0'
#              '</li>\n'
#              '<li>Investors should avoid a "buy-the-dip… [+2652 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Asia Martin',
#   'title': 'Leaked Amazon memo shows plans to reduce employee stock awards in '
#            '2025',
#   'description': 'Leaked Amazon memos, AI tricking reporters, and the late Bob '
#                  "Lee in today's 10 Things in Tech.",
#   'url': 'https://www.businessinsider.com/amazon-memo-ai-microsoft-tesla-toyota-chatgpt-cashapp-google-2025-2023-4',
#   'urlToImage': 'https://i.insider.com/642e9c5f2a659a0019a6a228?width=1200&format=jpeg',
#   'publishedAt': '2023-04-06T10:30:08Z',
#   'content': 'Welcome back to another day of tech news.\xa0\xa0Last week, Elon '
#              'Musk and a number of tech elites signed an open letter to put a '
#              "six month pause on developing AI. While it's obvious that AI has "
#              'the ability… [+4068 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Morgan Chittum',
#   'title': 'Charles Schwab stock just notched its worst month since 1987 as '
#            'fears of banking contagion flared',
#   'description': 'Schwab saw around $47 billion of market value erased in just '
#                  'a single month.',
#   'url': 'https://markets.businessinsider.com/news/stocks/charles-schwab-stock-price-bank-crisis-money-market-funds-inflation-2023-4',
#   'urlToImage': 'https://i.insider.com/642ad3d6fb9f05001953d783?width=1200&format=jpeg',
#   'publishedAt': '2023-04-03T15:29:55Z',
#   'content': 'A Charles Schwab branch in New York City.Photo by James '
#              'Leynse/Corbis via Getty Images\r\n'
#              '<ul>\n'
#              '<li>Shares of Charles Schwab tumbled 33% in March.</li>\n'
#              '<li>This resulted in more than $47 billion of the … [+2020 '
#              'chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Ryan Hogg',
#   'title': 'Elon Musk broke the law with a tweet about Tesla stock options, '
#            'court rules',
#   'description': 'The US 5th Circuit Court upheld a ruling by the NLRB saying '
#                  "the Tesla CEO broke the law by threatening employees' stock "
#                  'options if they unionized.',
#   'url': 'https://www.businessinsider.com/elon-musk-broke-law-with-tweet-about-tesla-stock-options-court-rules-2023-4',
#   'urlToImage': 'https://i.insider.com/63907cb28580f70019f7cd3c?width=1200&format=jpeg',
#   'publishedAt': '2023-04-01T12:03:58Z',
#   'content': 'Elon Musk is CEO of Tesla.Getty Images\r\n'
#              '<ul>\n'
#              '<li>Elon Musk broke labor law with a 2018 tweet about Tesla '
#              "employees' stock options, a court ruled.</li>\n"
#              '<li>The US 5th Circuit Court of Appeals said Mus… [+2389 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Carla Mozée',
#   'title': "Virgin Orbit stock crashes as Richard Branson's satellite company "
#            "ceases operations 'for the foreseeable future'",
#   'description': 'Virgin Orbit hasn\'t secured funding needed "to provide a '
#                  'clear path for this company," CEO Dan Hart told employees, '
#                  'according to CNBC.',
#   'url': 'https://markets.businessinsider.com/news/stocks/virgin-orbit-stock-price-satellite-ceases-operations-job-cuts-branson-2023-3',
#   'urlToImage': 'https://i.insider.com/63be8c9b06706e0019a9b9db?width=1200&format=jpeg',
#   'publishedAt': '2023-03-31T13:29:36Z',
#   'content': 'Virgin Orbit founder Richard Branson.Virgin Orbit\r\n'
#              '<ul>\n'
#              '<li>Virgin Orbit stock plunged Friday after the company said '
#              "it's cutting nearly all of its staff.\xa0</li>\n"
#              '<li>The satellite-launching company fo… [+1329 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Filip De Mott',
#   'title': 'ChatGPT can accurately parse Fed statements and anticipate stock '
#            'moves from corporate news, studies say',
#   'description': 'GPT-4, released in mid-March, was more likely to agree with '
#                  'humans than GPT-3, according to researchers at the Richmond '
#                  'Fed.',
#   'url': 'https://markets.businessinsider.com/news/stocks/chatgpt-fed-statements-fedspeak-predict-stocks-studies-artificial-intelligence-markets-2023-4',
#   'urlToImage': 'https://i.insider.com/643e94c82ddd0600182603cd?width=1200&format=jpeg',
#   'publishedAt': '2023-04-18T15:11:35Z',
#   'content': 'Bill Ready warns AI bots like ChatGPT could pose issues.Photo '
#              'Illustration by Rafael Henrique/SOPA Images/LightRocket via '
#              'Getty Images\r\n'
#              '<ul>\n'
#              '<li>One study found that ChatGPT reasons similarly to huma… '
#              '[+2332 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': 'AMC Entertainment plunges 23% after it settles lawsuit to convert '
#            'APE units into common stock',
#   'description': 'AMC shareholders had previously voted down a measure that '
#                  'would have given the company the authority to issue more '
#                  'stock to raise cash.',
#   'url': 'https://markets.businessinsider.com/news/stocks/amc-stock-price-settles-shareholder-lawsuit-convert-ape-reverse-split-2023-4',
#   'urlToImage': 'https://i.insider.com/642c2c44d335200018dd87e4?width=1200&format=jpeg',
#   'publishedAt': '2023-04-04T16:03:49Z',
#   'content': 'Adam Aron, Chairman of the Board and CEO, AMC Entertainment, '
#              'speaks at the 2021 Milken Institute Global Conference in Beverly '
#              'Hills, California, U.S., October 18, 2021.David '
#              'Swanson/Reuters\r\n'
#              '<ul><li>… [+2133 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'George Glover',
#   'title': "Tesla stock slides 8% as Elon Musk's price cuts eat into quarterly "
#            'profits',
#   'description': "Tesla's stock price slumped in premarket trading on Thursday "
#                  'after its first-quarter earnings disappointed Wall Street.',
#   'url': 'https://markets.businessinsider.com/news/stocks/tesla-stock-elon-musk-price-cuts-market-news-model-y-2023-4',
#   'urlToImage': 'https://i.insider.com/6440faa23f6f690018dea61c?width=1200&format=jpeg',
#   'publishedAt': '2023-04-20T09:22:40Z',
#   'content': "Tesla shares fell in Thursday's premarket with Elon Musk's price "
#              "cuts eating away at the EV maker's profit margins.Aly "
#              'Song/Reuters\r\n'
#              '<ul>\n'
#              '<li>Tesla stock fell 8% in premarket trading on Thursday afte… '
#              '[+1943 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Kyle Barr',
#   'title': 'Apple’s $3,000 VR Headset Reportedly Packs an External Battery '
#            'That Lasts Just Two Hours',
#   'description': 'Batteries still suck, especially if you’re trying to keep '
#                  'costs low and not weigh a device down with unnecessary '
#                  'lithium. That’s a problem for Apple and its upcoming '
#                  'mixed-reality headset. In his latest newsletter, Bloomberg’s '
#                  'Mark Gurman offered a few more h…',
#   'url': 'https://gizmodo.com/apple-vr-headset-1850368574',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/c96dfbea23051de83b3ec5943f1381cf.jpg',
#   'publishedAt': '2023-04-24T16:00:00Z',
#   'content': 'Batteries still suck, especially if youre trying to keep costs '
#              'low and not weigh a device down with unnecessary lithium. Thats '
#              'a problem for Apple and its upcoming mixed-reality headset. In '
#              'his lates… [+3358 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Stocks sink, JPMorgan surges after earnings: Stock market news '
#            'today - Yahoo Canada Finance',
#   'description': '<ol><li>Stocks sink, JPMorgan surges after earnings: Stock '
#                  'market news today\xa0\xa0Yahoo Canada Finance\r\n'
#                  '</li><li>The close: Wall Street dips as rate hike bets firm, '
#                  'banks jump\xa0\xa0The Globe and Mail\r\n'
#                  '</li><li>Wall St set for lower open as retail sales data '
#                  'offsets e…',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-14T17:03:54Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': None, 'name': 'The Guardian'},
#   'author': 'Jasper Jolly',
#   'title': 'First Spac set up under new UK rules to close after failing to '
#            'find merger target',
#   'description': 'Hambro Perks Acquisition Company blames ‘challenging '
#                  'circumstances’ for stock market listingsThe first company '
#                  'launched under Rishi Sunak’s newly relaxed rules to attract '
#                  'special purpose acquisition companies to London after Brexit '
#                  'has said it will shut down,…',
#   'url': 'https://www.theguardian.com/business/2023/apr/24/spac-new-uk-rules-close-hambro-perks-acquisition-company-stock-market',
#   'urlToImage': 'https://i.guim.co.uk/img/media/daaac6c599a52e6f79becb24c924b2100927f2eb/70_0_5813_3488/master/5813.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=bb7bb8a2913d0c2b14208b7109422002',
#   'publishedAt': '2023-04-24T08:38:32Z',
#   'content': 'The first company launched under Rishi Sunaks newly relaxed '
#              'rules to attract special purpose acquisition companies to London '
#              'after Brexit has said it will shut down, without finding a '
#              'suitable merger… [+3227 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Jennifer Sor',
#   'title': "Meta stock is a 'top pick' and could soar 20% as the social media "
#            'giant leans into the AI hype, analysts say',
#   'description': 'UBS analysts called Meta stock a "top pick," estimating '
#                  'shares could rally 20% to $280 over the next twelve months.',
#   'url': 'https://markets.businessinsider.com/news/stocks/meta-stock-price-earnings-reels-ai-internet-tech-stocks-outlook-2023-4',
#   'urlToImage': 'https://i.insider.com/6182ce95326b26001834a982?width=1200&format=jpeg',
#   'publishedAt': '2023-04-27T18:15:04Z',
#   'content': 'Facebook, now Meta, founder and CEO Mark Zuckerberg in '
#              '2020Getty\r\n'
#              '<ul>\n'
#              '<li>Meta is now a "top pick" among internet stocks as the '
#              'company leans into the AI hype, analysts say.</li>\n'
#              '<li>Shares of Meta … [+3142 chars]'},
#  {'source': {'id': 'google-news', 'name': 'Google News'},
#   'author': None,
#   'title': 'Big banks including JPMorgan see shares climb after results; '
#            'Boeing stock stumbles - MarketWatch',
#   'description': '<ol><li>Big banks including JPMorgan see shares climb after '
#                  'results; Boeing stock stumbles\xa0\xa0MarketWatch\r\n'
#                  '</li><li>Before the Bell: Futures muted ahead of U.S. bank '
#                  'results\xa0\xa0The Globe and Mail\r\n'
#                  '</li><li>Banks Are Set for Earnings Season. Are They Too '
#                  'Cheap to …',
#   'url': 'https://consent.google.com/ml?continue=https://news.google.?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#   'urlToImage': None,
#   'publishedAt': '2023-04-14T11:27:00Z',
#   'content': 'We use cookies and data to<ul><li>Deliver and maintain Google '
#              'services</li><li>Track outages and protect against spam, fraud, '
#              'and abuse</li><li>Measure audience engagement and site '
#              'statistics to unde… [+1131 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Morgan Chittum',
#   'title': 'Western Alliance soars 20% after it says deposits stabilized a '
#            'month after bank turmoil rocked markets',
#   'description': 'Wedbush upgraded the stock from neutral to outperform, '
#                  'citing deposit levels that give the regional lender a "solid '
#                  'outlook."',
#   'url': 'https://markets.businessinsider.com/news/stocks/western-alliance-stock-price-wedbush-analyst-bullish-outlook-regional-banks-2023-4',
#   'urlToImage': 'https://i.insider.com/644013c03f6f690018de8455?width=1200&format=jpeg',
#   'publishedAt': '2023-04-19T18:10:44Z',
#   'content': '(Photo Illustration by Pavlo Gonchar/SOPA Images/LightRocket via '
#              'Getty Images)\r\n'
#              '<ul>\n'
#              '<li>Western Alliance stock surged as much as 20% on '
#              'Wednesday.</li>\n'
#              '<li>The regional lender indicated that its dep… [+1987 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Joe Ciolli',
#   'title': "The stock market is unusually quiet right now. Here's why that "
#            "won't last, and why traders should sell on any bounce.",
#   'description': 'The stock market should be seeing bigger price swings than '
#                  "it is, considering all that's going on.",
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-outlook-forecast-volatility-vix-low-sell-bounces-jpmorgan-2023-4',
#   'urlToImage': 'https://i.insider.com/6446cb71120cd7001865e733?width=1200&format=jpeg',
#   'publishedAt': '2023-04-24T19:26:36Z',
#   'content': 'Associated Press\r\n'
#              '<ul>\n'
#              "<li>By multiple measures, the stock market is the calmest it's "
#              'been since the end of 2021.</li>\n'
#              '<li>JPMorgan quant guru Marko Kolanovic says the equity market '
#              'is far too placid… [+2899 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Morgan Chittum',
#   'title': 'Bed Bath & Beyond plummets as retailer announces new share sale '
#            'after ending deal with Hudson Bay',
#   'description': 'Bed Bath & Beyond said that if the sale of up to $300 '
#                  "million of new shares doesn't go through, its next move will "
#                  'likely be to file for bankruptcy.',
#   'url': 'https://markets.businessinsider.com/news/stocks/bed-bath-beyond-bbby-bankruptcy-hudson-bay-meme-stock-2023-3',
#   'urlToImage': 'https://i.insider.com/62ff9996f1df7e0018eb4d65?width=1200&format=jpeg',
#   'publishedAt': '2023-03-30T18:20:31Z',
#   'content': 'VIEW press/Getty Images\r\n'
#              '<ul>\n'
#              '<li>Shares of Bed Bath & Beyond fell as much as 24% on '
#              'Thursday.\xa0</li>\n'
#              '<li>The embattled retailer has filed to sell as much as $300 '
#              'million in stock to pay down debt.\xa0</… [+1216 chars]'},
#  {'source': {'id': None, 'name': 'The Guardian'},
#   'author': 'Michael Segalov',
#   'title': '‘I Googled “white guy” and there I was’: stock photo models on '
#            'seeing their faces in everything from ads to ridiculous memes',
#   'description': 'Some of them posed for photos – and before they knew it they '
#                  'had become the face of skin lightening, bad boyfriends, '
#                  'penis disorders and Canadian immigration. What’s it like '
#                  'when your image goes around the world?Stock images are '
#                  'everywhere, and you probably r…',
# ...
#                  'private equity’s long-predicted raid on the UK’s ranks of '
#                  'mid-sized quoted companies. Last week, Dechra '
#                  'Pharmaceuticals, a veterinary medicin…',
#   'url': 'https://www.theguardian.com/business/nils-pratley-on-finance/2023/apr/18/private-equity-london-stock-exchange-thg-john-wood',
#   'urlToImage': 'https://i.guim.co.uk/img/media/bab7955a4add8ebf0030db5e365d48c844190aec/0_289_4500_2701/master/4500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctb3BpbmlvbnMucG5n&enable=upscale&s=69ade99d270d62de2618fe469fe8d5bb',
#   'publishedAt': '2023-04-18T05:00:36Z',
#   'content': 'Here it is then: private equitys long-predicted raid on the UKs '
#              'ranks of mid-sized quoted companies. Last week, Dechra '
#              'Pharmaceuticals, a veterinary medicine group, said it had '
#              'received a potential c… [+4737 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Jennifer Sor',
#   'title': "Why one investor says Elon Musk's reign as CEO of Tesla, Twitter, "
#            "and SpaceX may be 'entering the end game'",
#   'description': 'Elon Musk could be entering the "end game" as Tesla, '
#                  'Twitter, and SpaceX CEO as the tech mogul faces his mountain '
#                  'of debt, one investor said.',
#   'url': 'https://markets.businessinsider.com/news/stocks/elon-musk-tesla-stock-price-twitter-debt-spacex-dan-nathan-2023-4',
#   'urlToImage': 'https://i.insider.com/5e32fe3862fa813a0c67ed14?width=1200&format=jpeg',
#   'publishedAt': '2023-04-21T20:29:01Z',
#   'content': 'Elon Musk.REUTERS/Steve Nesius\r\n'
#              '<ul>\n'
#              "<li>Elon Musk's days as CEO of three high-profile companies "
#              'might soon be over, investor Dan Nathan said.</li>\n'
#              "<li>Nathan pointed to Musk's mountain of debt from … [+2648 "
#              'chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'mfox@businessinsider.com (Matthew Fox)',
#   'title': 'The stock market just flashed the first sign that investors think '
#            'the Silicon Valley Bank crisis is over',
#   'description': '"If stocks do not make a new low post this crisis, the bears '
#                  'could capitulate," Fundstrat\'s Tom Lee said.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-signals-silicon-valley-banking-crisis-over-volatility-vix-2023-3',
#   'urlToImage': 'https://i.insider.com/5f9873330c60aa00190d4a3b?width=1200&format=jpeg',
#   'publishedAt': '2023-03-29T14:19:03Z',
#   'content': 'The stock market just flashed an important signal that suggests '
#              'the ongoing banking crisis that was sparked by the collapse of '
#              'Silicon Valley Bank earlier this month is over.\r\n'
#              "That's according to Fun… [+2099 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Filip De Mott',
#   'title': 'Bond yields could drop under an idea that would make Treasury '
#            'trading more like the stock market',
#   'description': "Federal regulators are studying what's known as all-to-all "
#                  'trading in the Treasury market amid liquidity concerns.',
#   'url': 'https://markets.businessinsider.com/news/bonds/bond-yields-treasury-market-liquidity-all-to-all-trading-debt-2023-4',
#   'urlToImage': 'https://i.insider.com/6442d72986be000018e50d8b?width=1200&format=jpeg',
#   'publishedAt': '2023-04-22T12:30:07Z',
#   'content': 'US Treasury Department.Patrick Semansky/AP\r\n'
#              '<ul>\n'
#              '<li>Treasury markets have a liquidity problem that was fueled by '
#              'regulatory changes after 2008.</li>\n'
#              '<li>All-to-all trading, similar to how equities o… [+3845 '
#              'chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Zinya Salfiti',
#   'title': 'Tesla saw a $56 billion stock rout in a single day, an amount that '
#            "dwarfs Ford's market cap",
#   'description': 'Tesla saw its value plunge by almost $56 billion in one day, '
#                  'an amount that dwarfs the individual market caps of Ford and '
#                  'General Motors.',
#   'url': 'https://markets.businessinsider.com/news/stocks/tesla-stock-price-market-cap-elon-musk-56-billion-starship-2023-4',
#   'urlToImage': 'https://i.insider.com/64428698169c060018964fac?width=1200&format=jpeg',
#   'publishedAt': '2023-04-21T13:40:07Z',
#   'content': 'Tesla electric cars charge at a Supercharger.George Rose/Getty '
#              'Images\r\n'
#              '<ul>\n'
#              '<li>Tesla saw its value plunge by almost $56 billion in one day, '
#              'an amount that dwarfs the individual market caps of Ford a… '
#              '[+1757 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Zinya Salfiti',
#   'title': 'Stock ETFs are seeing accelerated inflows even as grimmer Wall '
#            'Street predictions warn of a bear market ahead',
#   'description': 'Equity ETFs pulled in more than $12.6 billion this month, '
#                  'the largest inflow since January, and more than double the '
#                  'pace seen in February and March.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-etfs-big-inflows-bear-market-wall-street-ed-yardeni-2023-4',
#   'urlToImage': 'https://i.insider.com/6352c3fc390dfe00196d6dea?width=1200&format=jpeg',
#   'publishedAt': '2023-04-24T12:54:30Z',
#   'content': 'A big screen display of stock prices hangs behind traders '
#              'working at the New York Stock Exchange NYSE on May 9, '
#              '2022.Michael Nagle/Xinhua via Getty Images\r\n'
#              '<ul>\n'
#              '<li>Stock ETFs pulled in more than $12… [+2419 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'George Glover',
#   'title': 'Meta stock jumps 11% on earnings beat as Mark Zuckerberg touts AI '
#            'and vows to keep costs down',
#   'description': "Shares of Facebook, Instagram and WhatsApp's owner surged "
#                  'after its first-quarter revenue and earnings beat Wall '
#                  "Street's expectations.",
#   'url': 'https://markets.businessinsider.com/news/stocks/meta-stock-price-mark-zuckerberg-ai-year-of-efficiency-investing-2023-4',
#   'urlToImage': 'https://i.insider.com/644a329e9052390019701bd8?width=1200&format=jpeg',
#   'publishedAt': '2023-04-27T09:43:13Z',
#   'content': "Meta shares jumped in Thursday's premarket after the tech "
#              "giant's earnings beat Wall Street's expectations.Noah "
#              'Berger/Getty Images\r\n'
#              '<ul>\n'
#              "<li>Meta shares climbed 11% in Thursday's premarket after ear… "
#              '[+2295 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Jennifer Sor',
#   'title': 'Charles Schwab highlights a part of the stock market that will '
#            'outperform if interest rates stay high',
#   'description': 'Companies with immediate potential for cash-flow generation '
#                  'saw a 55% return over the past two years, beating the MSCI '
#                  "World Index's return of 18%.",
#   'url': 'https://markets.businessinsider.com/news/stocks/charles-schwab-stock-market-outlook-short-duration-high-interest-rates-2023-4',
#   'urlToImage': 'https://i.insider.com/6169c31141af0d00193ee3d3?width=1200&format=jpeg',
#   'publishedAt': '2023-04-11T14:15:43Z',
#   'content': 'Spencer Platt/Getty Images\r\n'
#              '<ul>\n'
#              "<li>There's an area of the stock market that will outperform "
#              'amid higher interest rates, Charles Schwab said.</li>\n'
#              '<li>The bank pointed to short-duration stocks, whic… [+2520 '
#              'chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Morgan Chittum',
#   'title': 'Retail investors are sitting on big losses in their stock '
#            'portfolios even as the market rallies in 2023',
#   'description': '"This prolonged bear market – particularly in tech - along '
#                  'with recent growing fears of a recession are undoubtedly '
#                  'weighing on sentiment."',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-rally-retail-investors-portfolio-losses-tesla-apple-nvidia-2023-4',
#   'urlToImage': 'https://i.insider.com/64397c2c75412f0018d5737a?width=1200&format=jpeg',
#   'publishedAt': '2023-04-14T18:08:40Z',
#   'content': 'Sesame/Getty Images\r\n'
#              '<ul>\n'
#              '<li>The average retail investor portfolio is down 27% '
#              'year-to-date, per VandaTrack.</li>\n'
#              '<li>US stocks have been surprisingly resilient in 2023 despite '
#              'looming recession fea… [+2381 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': "The stock market is facing a 'pain trade' that suggests the latest "
#            'rally will extend into April',
#   'description': '"Why is April usually strong? It could be a combination of '
#                  'springtime buying, good riddance to winter, or putting tax '
#                  'refunds to work."',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-pain-trade-latest-rally-extend-april-bearish-sentiment-2023-3',
#   'urlToImage': 'https://i.insider.com/5f36baabe89ebf001f044a3d?width=1200&format=jpeg',
#   'publishedAt': '2023-04-02T12:16:09Z',
#   'content': 'Drew Angerer/Getty Images\r\n'
#              '<ul><li>The stock market has a knack for doing the opposite of '
#              "what most people think it will do, and that's what's playing out "
#              'right now.</li><li>Despite the bank failures… [+3227 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'mfox@businessinsider.com (Matthew Fox)',
#   'title': 'The stock market rally is over as commercial real estate risks '
#            "begin to compound, JPMorgan's chief market strategist says",
#   'description': '"Commercial real estate stresses appear to be compounding, '
#                  'amplified by banking shocks that could complicate their debt '
#                  'roll," Marko Kolanovic warned.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-rally-over-commercial-real-estate-threatens-banks-jpmorgan-2023-3',
#   'urlToImage': 'https://i.insider.com/6421e07755bd920018e1f34c?width=1200&format=jpeg',
#   'publishedAt': '2023-03-27T18:31:39Z',
#   'content': 'The stock market rally that began in mid-October and extended '
#              "through the first quarter of 2023 is nearing its end, and it'll "
#              'be downhill from here, according to JPMorgan chief global market '
#              'strategi… [+2724 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': 'Better than feared first quarter earnings results will power the '
#            'stock market to new highs, Fundstrat says',
#   'description': '"We think demand and margins holding up better will support '
#                  'a rally in technology stocks... Technology could be the '
#                  'winner of results season."',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-rally-strong-q1-earnings-better-than-feared-outlook-2023-4',
#   'urlToImage': 'https://i.insider.com/5f45216742f43f001ddfed58?width=1200&format=jpeg',
#   'publishedAt': '2023-04-21T14:59:50Z',
#   'content': 'Cindy Ord/Getty Images\r\n'
#              '<ul><li>Better than feared earnings results will power the stock '
#              "market's ongoing rally, according to Fundstrat's Tom "
#              'Lee.</li><li>Of the near 20% of S&P 500 companies that ha… '
#              '[+2613 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'prosen@insider.com (Phil Rosen)',
#   'title': 'Alibaba stock jumps 10% as the Chinese tech giant begins its '
#            'biggest reorganization ever and eyes new IPOs',
#   'description': 'The move to split the company into six independently run '
#                  'entities comes just a day after cofounder Jack Ma was seen '
#                  'in China after almost a year away.',
#   'url': 'https://markets.businessinsider.com/news/stocks/alibaba-stock-price-chinese-tech-giant-overhaul-ipo-jack-ma-2023-3',
#   'urlToImage': 'https://i.insider.com/6422df588c966b0019499b47?width=1200&format=jpeg',
#   'publishedAt': '2023-03-28T13:07:34Z',
#   'content': 'Shares of Alibaba Group Holding jumped 10% Tuesday following the '
#              "company's announcement that it would begin its largest "
#              'restructuring ever.\r\n'
#              'The news comes just a day after cofounder Jack Ma was seen… '
#              '[+1154 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Matthew Fox',
#   'title': "Nintendo stock jumps after 'The Super Mario Bros. Movie' breaks "
#            'records in $377 million box office haul',
#   'description': 'JPMorgan said it expects the Mario movie will ultimately '
#                  'surpass Frozen II in its total box office revenue, '
#                  'generating more than $1.45 billion.',
#   'url': 'https://markets.businessinsider.com/news/stocks/nintendo-stock-price-super-mario-bros-movie-box-office-records-2023-4',
#   'urlToImage': 'https://i.insider.com/643451153007470019fe5674?width=1200&format=jpeg',
#   'publishedAt': '2023-04-10T19:20:31Z',
#   'content': 'Mario and Luigi in "The Super Mario Bros. Movie."Universal\r\n'
#              '<ul>\n'
#              '<li>Nintendo stock jumped on Monday following the successful '
#              'release of "The Super Mario Bros. Movie."</li>\n'
#              '<li>The movie smashed box-… [+3649 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'George Glover',
#   'title': 'Brace for stock-market volatility to persist this year as '
#            'investors get bombarded with economic data, UBS says',
#   'description': '"The potential remains for this data-dependent market to '
#                  'keep jumping from one narrative to another for the rest of '
#                  'the year," UBS\'s investment chief said.',
#   'url': 'https://markets.businessinsider.com/news/stocks/stock-market-outlook-inflation-economic-data-unemployment-ubs-mark-haefele-2023-4',
#   'urlToImage': 'https://i.insider.com/61fd424eb0ec040018d0d8f1?width=1200&format=jpeg',
#   'publishedAt': '2023-04-12T09:49:39Z',
#   'content': "Stock prices aren't going to make much sense the rest of this "
#              'year with investors grappling with waves of confusing economic '
#              'data, according to UBS.Richard Drew/Associated Press\r\n'
#              '<ul>\n'
#              '<li>Stock price… [+2863 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Zinya Salfiti',
#   'title': 'Signature Bank top execs led $100 million in insider stock sales '
#            "in the years leading up to the lender's collapse",
#   'description': 'While Signature Bank was pivoting its business in recent '
#                  'years to become more crypto-focused, some top executives '
#                  'were cutting their stakes, the WSJ reported.',
#   'url': 'https://markets.businessinsider.com/news/currencies/signature-bank-insiders-100-million-stock-sale-collapse-top-execs-2023-4',
#   'urlToImage': 'https://i.insider.com/642bdec7fcb86b0018030759?width=1200&format=jpeg',
#   'publishedAt': '2023-04-04T10:25:08Z',
#   'content': 'A worker arrives at the Signature Bank headquarters in New York '
#              'City, U.S., March 12, 2023.REUTERS/Eduardo Munoz\r\n'
#              '<ul>\n'
#              '<li>Insiders at Signature Bank offloaded $100 million of its '
#              'stock in the 3 year… [+1478 chars]'}]
# get news
